# %%
# calculatrice
print("Bienvenue dans ma première calculatrice V1.0 - tidjaha copyrights- \n")
arret = "O"
while arret!="N" and arret!="n":
  a=float(input("Entrer le premier nombre pour une operation : a = "))
  b=float(input("Entrer le deuxième nombre : b = "))
  print("Que Voulez Vous Faire ? \n TAPEZ : \n 0- Choisir d'autres nombres \n 1- L'addition (a+b) \n 2- Soustraction (a-c) \n 3- Multiplication (a*b) \n 4- Division (a/b) ")
  choix=int(input("Votre choix est : "))
  if choix==0:
    continue
  elif choix==1:
    c=a+b
    print("Le resultat de a+b est : ", c)
  elif choix==2:
    c=a-b
    print("Le resultat de a-b est : ", c)
  elif choix==3:
    c=a*b
    print("Le resultat de a*b est : ", c)
  else :
    c=a/b
    print("Le resultat de a/b est : ", c)
  arret=input("Voulez Vous Faire d'Autres Nombres ? \n Tapez 'O' pour continuer ou Tapez 'N' pour arreter et sortir : ")

# %%
# calculatrice (nouvelle version optimisation sur le programme)
print("Bienvenue dans ma première calculatrice V1.11 - tidjaha copyrights- \n")
arret = "O"
while arret!="N" and arret!="n":
   while True:
     a=input("Entrer le premier nombre pour une operation : a = ")
     try:
       a = float(a)
       break
     except ValueError:
      print("ENTRER UN NOMBRE VALIDE SVP")
   while True:
     b=input("Entrer le premier nombre pour une operation : b = ")
     try:
       b = float(b)
       break
     except ValueError:
      print("ENTRER UN NOMBRE VALIDE SVP")
   t=1
   while t==1:
    print("Que Voulez Vous Faire ? \n TAPEZ : \n 0- Choisir d'autres nombres \n 1- L'addition (a+b) \n 2- Soustraction (a-c) \n 3- Multiplication (a*b) \n 4- Division (a/b) ")
    choix=input("Votre choix est : ")
    if choix=="0":
     continue
     t=t+1
    elif choix=="1":
     c=a+b
     print("Le resultat de a+b est : ", c)
     t=t+1
    elif choix=="2":
     c=a-b
     t=t+1
     print("Le resultat de a-b est : ", c)
    elif choix=="3":
     c=a*b
     print("Le resultat de a*b est : ", c)
     t=t+1
    elif choix=="4" :
     c=a/b
     t=t+1
     print("Le resultat de a/b est : ", c)
    else:
     print("             ****SVP**** \n entrer votre choix en tapant \n    *** un chiffre entre 0 et 4**** ")
   arret=input("Voulez Vous Faire d'Autres Nombres ? \n Tapez 'O' pour continuer ou Tapez 'N' pour arreter et sortir : ")
# Out:
# Bienvenue dans ma première calculatrice V1.11 - tidjaha copyrights-
#
# Entrer le premier nombre pour une operation : a = 2a
# ENTRER UN NOMBRE VALIDE SVP
# Entrer le premier nombre pour une operation : a = 2.2a
# ENTRER UN NOMBRE VALIDE SVP
# Entrer le premier nombre pour une operation : a = 3a
# ENTRER UN NOMBRE VALIDE SVP
# Entrer le premier nombre pour une operation : a = &
# ENTRER UN NOMBRE VALIDE SVP
# Entrer le premier nombre pour une operation : a = 2.2
# Entrer le premier nombre pour une operation : b = 3.2
# Que Voulez Vous Faire ?
#  TAPEZ :
#  0- Choisir d'autres nombres
#  1- L'addition (a+b)
#  2- Soustraction (a-c)
#  3- Multiplication (a*b)
#  4- Division (a/b)
# Votre choix est : &
#              ****SVP****
#  entrer votre choix en tapant
#     *** un chiffre entre 0 et 4****
# Que Voulez Vous Faire ?
#  TAPEZ :
#  0- Choisir d'autres nombres
#  1- L'addition (a+b)
#  2- Soustraction (a-c)
#  3- Multiplication (a*b)
#  4- Division (a/b)
# Votre choix est : 5&
# ...

# %%
# calculatrice (nouvelle version correction des erreurs si l'utilisateur tape autre qu'un chiffre)
print("Bienvenue dans ma première calculatrice V1.1 - tidjaha copyrights- \n")
arret = "O"
while arret!="N" and arret!="n":
  n=0
  j=1
  r=0
  while j==1:
   a=input("Entrer le premier nombre pour une operation : a = ")
   l=len(a)
   n=0
   for i in a:
    n=n+1
    j=1
    if n==1:
     if i=="-":
      if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i=="+":
      if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i==".":
       if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("ENTRER UN CHIFFRE SVP")
      break
    else:
     if i==".":
        r=r+1
        if r>1:
            print("ENTRER UN CHIFFRE SVP")
            break
        else:
           j=j+1
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("ENTRER UN CHIFFRE SVP")
      break
  a=float(a)
  n=0
  j=1
  r=0
  while j==1:
   b=input("Entrer le premier nombre pour une operation : b = ")
   l=len(b)
   n=0
   for i in b:
    n=n+1
    j=1
    if n==1:
     if i=="-":
      if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i=="+":
      if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i==".":
       if l==1:
        print("ENTRER UN CHIFFRE SVP")
        break
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("ENTRER UN CHIFFRE SVP")
      break
    else:
     if i==".":
        r=r+1
        if r>1:
            print("ENTRER UN CHIFFRE SVP")
            break
        else:
           j=j+1
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("ENTRER UN CHIFFRE SVP")
      break
  b=float(b)

  t=1
  while t==1:
   print("Que Voulez Vous Faire ? \n TAPEZ : \n 0- Choisir d'autres nombres \n 1- L'addition (a+b) \n 2- Soustraction (a-c) \n 3- Multiplication (a*b) \n 4- Division (a/b) ")
   choix=input("Votre choix est : ")
   if choix=="0":
    continue
    t=t+1
   elif choix=="1":
    c=a+b
    print("Le resultat de a+b est : ", c)
    t=t+1
   elif choix=="2":
    c=a-b
    t=t+1
    print("Le resultat de a-b est : ", c)
   elif choix=="3":
    c=a*b
    print("Le resultat de a*b est : ", c)
    t=t+1
   elif choix=="4" :
    c=a/b
    t=t+1
    print("Le resultat de a/b est : ", c)
   else:
    print("             ****SVP**** \n entrer votre choix en tapant \n    *** un chiffre entre 0 et 4**** ")
  2
  arret=input("Voulez Vous Faire d'Autres Nombres ? \n Tapez 'O' pour continuer ou Tapez 'N' pour arreter et sortir : ")

# %%
valeur=[[1],[1]]
for i in range(2):
  if i!=1:
    valeur[i]=input("Entrer le premier nombre pour une operation : a = ")
    a=valeur[i]
    while not a.isdigit():
       print("veuillez entrer un chiffre")
       valeur[i]=input("Entrer le premier nombre pour une operation : a = ")
       a=valeur[i]
    a=float(a)
  else:
    valeur[i]=input("Entrer le deuxième nombre pour une operation : b = ")
    b=valeur[i]
    while not b.isdigit():
       print("veuillez entrer un chiffre")
       valeur[i]=input("Entrer le premier nombre pour une operation : a = ")
       b=valeur[i]
    b=float(b)

# %%
n=0
j=1
r=0
while j==1:
  a=input("a=")
  l=len(a)
  n=0
  for i in a:
    print(i)
    n=n+1
    j=1
    if n==1:
     if i=="-":
      if l==1:
        print("Entrer un CHIFFRE SVP")
        break
     elif i=="+":
      if l==1:
        print("Entrer un CHIFFRE SVP")
        break
     elif i==".":
       if l==1:
        print("Entrer un CHIFFRE SVP")
        break
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("Entrer un CHIFFRE SVP")
      break
    else:
     if i==".":
        r=r+1
        if r>1:
            print("Entrer un CHIFFRE SVP")
            break
        else:
           j=j+1
     elif i=="0":
      j=j+1
     elif i=="1":
      j=j+1
     elif i=="2":
      j=j+1
     elif i=="3":
      j=j+1
     elif i=="4":
      j=j+1
     elif i=="5":
      j=j+1
     elif i=="6":
      j=j+1
     elif i=="7":
      j=j+1
     elif i=="8":
      j=j+1
     elif i=="9":
      j=j+1
     else:
      print("Entrer un CHIFFRE SVP")
      break
a=float(a)
print("a=",type(a),a)

# %%
a=.2
a=float(a)
print(a)
# Out:
# 0.2

# %%
print("Que Voulez Vous Faire ? \n TAPEZ : \n 0- Choisir d'autres nombres \n 1- L'addition (a+b) \n 2- Soustraction (a-c) \n 3- Multiplication (a*b) \n 4- Division (a/b) ")
  choix=int(input("Votre choix est : "))
  if choix==0:
    continue
  elif choix==1:
    c=a+b
    print("Le resultat de a+b est : ", c)
  elif choix==2:
    c=a-b
    print("Le resultat de a-b est : ", c)
  elif choix==3:
    c=a*b
    print("Le resultat de a*b est : ", c)
  elif choix==4 :
    c=a/b
  else:

# %%
from tkinter import *
from tkinter import ttk

frm = ttk.Frame(padding=10)
frm.grid()
ttk.Label(frm, text="Hello World!").grid(column=0, row=0)
ttk.Button(frm, text="Quit", command=root.destroy).grid(column=1, row=0)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-4-5de3b2981233> in <cell line: 4>()
#       2 from tkinter import ttk
#       3
# ----> 4 frm = ttk.Frame(padding=10)
#       5 frm.grid()
#       6 ttk.Label(frm, text="Hello World!").grid(column=0, row=0)
#
# /usr/lib/python3.10/tkinter/ttk.py in __init__(self, master, **kw)
#     733             borderwidth, relief, padding, width, height
#     734         """
# --> 735         Widget.__init__(self, master, "ttk::frame", kw)
#     736
#     737
#
# /usr/lib/python3.10/tkinter/ttk.py in __init__(self, master, widgetname, kw)
#     546             readonly, alternate, invalid
#     547         """
# --> 548         master = setup_master(master)
#     549         if not getattr(master, '_tile_loaded', False):
#     550             # Load tile now, if needed
#
# ...
