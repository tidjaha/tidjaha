# %%
def ajouter_noeud(graph, n) :
  graph[n]=[]
  return print(graph)
def supprimer_noeud(graph, noeud):
  graph.pop(noeud)
  for i in graph:

      try:
         graph[i].remove(noeud)
         #break
      except  ValueError :
        pass
        #break
  return graph
def ajouter_lien(graph, noeud1, noeud2):
  graph[noeud1].append(noeud2)
  graph[noeud2].append(noeud1)
  return graph

def supprimer_lien(graph,noeud1,noeud2):
  graph[noeud1].remove(noeud2)
  graph[noeud2].remove(noeud1)
  return graph
graph = {'A': ['B','C'],'B': ['A','D','E'],'C': ['A','F'],'D': ['B'],'E': ['B','F'],'F': ['C','E']}
ajouter_noeud(graph, "G")
print(supprimer_noeud(graph, "B"))
#print(ajouter_lien(graph, "B", "G"))
#print(supprimer_lien(graph,"B","D"))
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D', 'E'], 'C': ['A', 'F'], 'D': ['B'], 'E': ['B', 'F'], 'F': ['C', 'E'], 'G': []}
# {'A': ['C'], 'C': ['A', 'F'], 'D': [], 'E': ['F'], 'F': ['C', 'E'], 'G': []}

# %%
def ajouter_noeud(graph, n) :
  graph[n]=[]
  return print(graph)
def supprimer_noeud(graph, noeud):
  graph.pop(noeud)
  for i in graph:
     for j in graph[i]:
        if j==noeud:
          graph[i].remove(j)
  return graph
def ajouter_lien(graph, noeud1, noeud2):
  graph[noeud1].append(noeud2)
  graph[noeud2].append(noeud1)
  return graph

def supprimer_lien(graph,noeud1,noeud2):
  graph[noeud1].remove(noeud2)
  graph[noeud2].remove(noeud1)
  return graph
graph = {'A': ['B','C'],'B': ['A','D','E'],'C': ['A','F'],'D': ['B'],'E': ['B','F'],'F': ['C','E']}
ajouter_noeud(graph, "G")
print(supprimer_noeud(graph, "B"))
#print(ajouter_lien(graph, "B", "G"))
#print(supprimer_lien(graph,"B","D"))
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D', 'E'], 'C': ['A', 'F'], 'D': ['B'], 'E': ['B', 'F'], 'F': ['C', 'E'], 'G': []}
# {'A': ['C'], 'C': ['A', 'F'], 'D': [], 'E': ['F'], 'F': ['C', 'E'], 'G': []}
